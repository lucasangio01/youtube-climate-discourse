# %%
import pandas as pd
import os
from dotenv import load_dotenv
from googleapiclient.discovery import build
from utils import *
import spacy

# %%
load_dotenv()

yt_api_key = os.getenv("YT_API_KEY")
youtube = build("youtube", "v3", developerKey = yt_api_key)

# %%
yt_videos = pd.read_csv("../yt_videos.csv")
yt_videos.tail()
# Out:
#                                                 title     video_id  \
# 23  “The Climate Change Agenda Is A Hoax” - Vivek ...  keUPHwFFQj4
# 24  It's Time To Acknowledge The Climate Crisis Fo...  Wwoq4Yikfko
# 25  Fox News is Definitely Certain that Climate Ch...  nBnVeh9udkk
# 26  BREAKING | Trump At UN: 'Climate Change Is The...  QTLmVwZHQyw
# 27        Donald Trump's Best Lines on Climate Change  qpyFjUsm2PU
#
#             channel                                         transcript
# 23  Vivek Ramaswamy  young people in this country are so hungry for...
# 24  Vivek Ramaswamy  Vic ramaswamy is the founder and executive cha...
# 25         Fox News  you don't go see Joseph goal's films to see th...
# 26     Donald Trump  air conditioner is like very uncommon to see o...
# 27     Donald Trump  and I think I know more about the environment ...

# %%
stance_targets = ["The person is in favor of climate change policies", "The person is opposed to the climate change policies", "The person has a neutral stance on climate change policies"]

# %% [markdown]
# # Data preprocessing workflow
#
# 1. __Split text__ --> for each video, split text into chunks of about 250 words, each chunk will end up on one different row (for model limits).
# 2. __Add punctuation__ --> add punctuation to each chunk with a punctuation restoration model (transformer)
# 3. __Check similarity to topic__ --> for each chunk (row) compute semantic similarity with some phrases (like "climate", "global warming", etc)
# 3. __Filter by similarity__ -->only keep the chunks that have semantic similarity > threshold (like 0.3 or 0.4 for cosine similarity)
# 4. __Tokenize__ -->tokenize filtered chunks for stance detection

# %%
yt_videos.head(1)
transcript_1 = yt_videos["transcript"].iloc[1]
transcript_1
# Out:
# "every day I learn a new fact that scares the crap out of me when it comes to climate so this is an axios a new study says a key Atlantic Ocean circulation could shut down by mid century so here's a little picture of it here the way the circulation works in the Atlantic it's actually really interesting a key element driving the Atlantic Ocean May dramatically dramatically slow down and then turn off completely during the next few decades a new study finds the circulation known as the Atlantic meritonial Meridian overturning circulation or the amok amoc includes the Gulf Stream part of a global conveyor belt that moves water around the world the amok helps to regulate everything from the rate of sea level rise on the east coast to Europe's average temperatures a sudden shutdown of this ocean current which the new study shows could occur during mid-century or between 2025 and 2095 was part of the plot of the 2004 disaster film The Day After Tomorrow do you guys remember that movie We're literally now bringing about in reality Day After Tomorrow stuff the research published Tuesday in the journal Nature Communications uses statistical methods to tease out early warning signals of an amok collapse including a Slowdown in the current and increasing variability the findings also suggest the shutdown may happen sooner than previously thought and perhaps within many people's lifetimes a breakdown would likely be potentially irreversible and would Mark a major Tipping Point critical thresholds in Earth's climate system that when crossed will usher in severe changes climate models indicate that an abrupt stop could trigger extreme cooling across parts of the northern hemisphere rainfall patterns around the world would be disrupted and major floods and storms would increase leading to further sea level rise in the North Atlantic Basin among other effects they say when they talk about extreme cooling I saw this in a different article on the same topic they say that uh in like like the UK for example northern Europe sort of area that that would go into to extreme cooling now I'm sure if slash when that happens you'll have a conservative turn around and say whatever I thought it was global warming and look there's massive cooling going on here no the reason why they changed the terminology to climate change is to be more accurate because the fact of the matter is even though the trend over time is warming and that line is very clear the climate truly is warming the weather even is warming it's true that you're going to have all sorts of issues pop up with severe weather on both ends of the spectrum and this is one of those things as a direct result of climate change this circulation could stop and then you'll have some places that get super freaking cold totally Haywire our system's gone totally Haywire we're talking about drought we're talking about famine we're talking about wars over water we're talking about some places you can't even live we're talking about increased extreme weather events the list goes on and on while the precise effects of a collapse aren't fully understood scientists believe it would have vast socioeconomic consequences for tens of millions of people acutely impacting coastal cities agriculture that's terrifying if it's going to affect our agriculture how do we know everything's going to be okay where we can feed everybody fish populations and marine ecosystems detailed observations of this circulation pattern via modern instruments are relatively short the study notes the scientists extended records further Back In Time by using sea surface temperatures to shed light on Trends the authors also noted they couldn't rule out overlooked or undiscovered mechanisms not reflected in their assessment the amoc is a system of ocean currents that transport water and heat between the Southern Ocean and the far North Atlantic Ocean in a years-long cycle that influences weather patterns in both hemispheres the currents are driv ...

# %%
len(transcript_1.split())
# Out:
# 1208

# %%
nlp = spacy.load("en_core_web_sm")
text = transcript_1
doc = nlp(text)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 nlp = spacy.load("en_core_web_sm")
#       2 text = transcript_1
#       3 doc = nlp(text)
#
# File c:\Users\sangi\Documents\GitHub\nlp-politics\.venv\Lib\site-packages\spacy\__init__.py:52, in load(name, vocab, disable, enable, exclude, config)
#      28 def load(
#      29     name: Union[str, Path],
#      30     *,
#    (...)     35     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      36 ) -> Language:
#      37     """Load a spaCy model from an installed package or a local path.
#      38
#      39     name (str): Package name or model path.
#    (...)     50     RETURNS (Language): The loaded nlp object.
#      51     """
# ---> 52     return util.load_model(
#      53         name,
#      54         vocab=vocab,
#      55         disable=disable,
#      56         enable=enable,
#      57         exclude=exclude,
#      58         config=config,
#      59     )
#
# File c:\Users\sangi\Documents\GitHub\nlp-politics\.venv\Lib\site-packages\spacy\util.py:484, in load_model(name, vocab, disable, enable, exclude, config)
#     482 if name in OLD_MODEL_SHORTCUTS:
#     483     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 484 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.
